# %% [markdown]
# # 0 - Temporary Notebook
# ---
# Note: **This notebook is used for functional testing only.**
#
# Last Update: Utilize `src/util.py` to load train input.

# %%
# Import required libraries.
from src import util

# %% [markdown]
# ## Load Config

# %%
# Load the configuration file.
CONFIG_DIR = "./config/config.yaml"
config = util.load_config(CONFIG_DIR)

# %%
# Load the train input.
X_train_path = config["path_train_set"][0]
X_train = util.pickle_load(file_path = X_train_path)
X_train.head()
# Out:
#        Patient_ID  Age  Gender  Tumor_Size   Location        Histology Stage  \
# 19881       19882   50    Male    7.544846   Parietal     Glioblastoma    II
# 17740       17741   46    Male    1.450586   Temporal  Medulloblastoma    II
# 5361         5362   30  Female    1.108693   Parietal  Medulloblastoma    IV
# 12735       12736   38  Female    4.576600  Occipital       Meningioma    IV
# 16230       16231   57    Male    3.043994   Parietal      Astrocytoma     I
#
#       Symptom_1      Symptom_2      Symptom_3 Radiation_Treatment  \
# 19881    Nausea       Seizures         Nausea                  No
# 17740    Nausea  Vision Issues       Headache                  No
# 5361   Seizures  Vision Issues       Seizures                  No
# 12735  Seizures         Nausea  Vision Issues                 Yes
# 16230    Nausea       Seizures       Seizures                 Yes
#
#       Surgery_Performed Chemotherapy  Survival_Rate  Tumor_Growth_Rate  \
# ...
